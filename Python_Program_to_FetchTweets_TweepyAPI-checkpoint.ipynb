# %%
import tweepy 
import pandas as pd
import sys
import csv
#from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import re
#from PIL import Image
#import pandas_profiling

# %%
import twitter
#you will need your own developer account

# %%
from twitter import Twitter
from twitter import OAuth

# %%
apikey='7ZXiKCFPHgGfm6wrAB1JMJros'
apisecretkey='yXr6dPMw9Pj5XcbXTqGGrhiXc5xZVYgy7ikhdGXIseNWiy9a6s'
accesstoken='903725577311576064-djBuT40JiqGbHU9OJnN41IiXVQckHlm'
accesstokensecret='u7ZO27QFtCeArwuefzJcTqz0GXPGY7HgQxqq8oFL3GR7X'

# %%
oauth = OAuth(accesstoken,accesstokensecret,apikey,apisecretkey)
api = Twitter(auth=oauth)

# %%
import tweepy

# %%
def get_tweets(username): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler('7ZXiKCFPHgGfm6wrAB1JMJros', 'yXr6dPMw9Pj5XcbXTqGGrhiXc5xZVYgy7ikhdGXIseNWiy9a6s') 
  
        # Access to user's access key and access secret 
        auth.set_access_token('903725577311576064-djBuT40JiqGbHU9OJnN41IiXVQckHlm', 'u7ZO27QFtCeArwuefzJcTqz0GXPGY7HgQxqq8oFL3GR7X') 
  
        # Calling api 
        api = tweepy.API(auth) 
        #set count to however many tweets you want - max count is 3200 and this doesn't have any effect if it is more than 3200
#        number_of_tweets = 5000
       
        tfile = []
        for tweet in tweepy.Cursor(api.user_timeline, screen_name = username).items():

        #username, tweet id, date/time, text
            tfile.append([username, tweet.id_str,tweet.source, tweet.created_at,tweet.retweet_count,tweet.favorite_count, tweet.text.encode("utf-8")])

	#write to a new csv file from the array of tweets
        outfile = username + "_tweets_V1.csv"
        print ("writing to " + outfile)
        with open(outfile, 'w+') as file:
            writer = csv.writer(file, delimiter=',')
            writer.writerow(['User_Name', 'Tweet_ID', 'Source', 'Created_date','Retweet_count','Favorite_count','Tweet'])
            writer.writerows(tfile)

# %%
df1.shape
# Out:
# (3134, 7)

# %%
def get_tweets(username): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler('7ZXiKCFPHgGfm6wrAB1JMJros', 'yXr6dPMw9Pj5XcbXTqGGrhiXc5xZVYgy7ikhdGXIseNWiy9a6s') 
  
        # Access to user's access key and access secret 
        auth.set_access_token('903725577311576064-djBuT40JiqGbHU9OJnN41IiXVQckHlm', 'u7ZO27QFtCeArwuefzJcTqz0GXPGY7HgQxqq8oFL3GR7X') 
  
        # Calling api 
        api = tweepy.API(auth) 
        #set count to however many tweets you want - max count is 3200 and this doesn't have any effect if it is more than 3200
#        number_of_tweets = 5000
       
        tfile = []
        for tweet in tweepy.Cursor(api.user_timeline, user_id= username).items():

        #username, tweet id, date/time, text
            tfile.append([username, tweet.id_str,tweet.source, tweet.created_at,tweet.retweet_count,tweet.favorite_count, tweet.text.encode("utf-8")])

	#write to a new csv file from the array of tweets
        outfile = username + "_tweets_V1.csv"
        print ("writing to " + outfile)
        with open(outfile, 'w+') as file:
            writer = csv.writer(file, delimiter=',')
            writer.writerow(['User_Name', 'Tweet_ID', 'Source', 'Created_date','Retweet_count','Favorite_count','Tweet'])
            writer.writerows(tfile)
            
# user name
get_tweets("1165551257886580736")
# Out:
# writing to 1165551257886580736_tweets_V1.csv

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Madhur Bhalkar'

# %%
def get_tweets1(username): 
          
        # Authorization to consumer key and consumer secret 
        auth = tweepy.OAuthHandler('7ZXiKCFPHgGfm6wrAB1JMJros', 'yXr6dPMw9Pj5XcbXTqGGrhiXc5xZVYgy7ikhdGXIseNWiy9a6s') 
  
        # Access to user's access key and access secret 
        auth.set_access_token('903725577311576064-djBuT40JiqGbHU9OJnN41IiXVQckHlm', 'u7ZO27QFtCeArwuefzJcTqz0GXPGY7HgQxqq8oFL3GR7X') 
  
        # Calling api 
        api = tweepy.API(auth) 
        #set count to however many tweets you want - max count is 3200 and this doesn't have any effect if it is more than 3200
        #number_of_tweets = 5000
       
        tfile = []
        for tweet in tweepy.Cursor(api.user_timeline, screen_name = username).items():

        #username, tweet id, date/time, text
            tfile.append([username, tweet.id_str,tweet.source, tweet.created_at,tweet.retweet_count,tweet.favorite_count, tweet.text.encode("utf-8")])

	#write to a new csv file from the array of tweets
        outfile = username + "_tweets_V1.csv"
        print ("writing to " + outfile)
        with open(outfile, 'w+') as file:
            writer = csv.writer(file, delimiter=',')
            writer.writerow(['User_Name', 'Tweet_ID', 'Source', 'Created_date','Retweet_count','Favorite_count','Tweet'])
            writer.writerows(tfile)

# %%
# user name
get_tweets1("@ScaryMommy")
# Out:
# writing to @ScaryMommy_tweets_V1.csv

# %%
 dfa=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/@eboland11_tweets_V1.csv",encoding='utf-8')

# %%
dfb=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/@LilNasX_tweets_V1.csv",encoding='utf-8')

# %%
dfb
# Out:
#      User_Name             Tweet_ID              Source         Created_date  \
# 0     @LilNasX  1160968780668755968  Twitter for iPhone  2019-08-12 17:38:21
# 1     @LilNasX  1160771298047299586  Twitter for iPhone  2019-08-12 04:33:38
# 2     @LilNasX  1160650579464470528  Twitter for iPhone  2019-08-11 20:33:56
# 3     @LilNasX  1160641494086119424  Twitter for iPhone  2019-08-11 19:57:50
# 4     @LilNasX  1160641226309193728  Twitter for iPhone  2019-08-11 19:56:46
# 5     @LilNasX  1160640418637209600  Twitter for iPhone  2019-08-11 19:53:34
# 6     @LilNasX  1160622164908728320  Twitter for iPhone  2019-08-11 18:41:02
# 7     @LilNasX  1160614879042011137  Twitter for iPhone  2019-08-11 18:12:05
# 8     @LilNasX  1160611656705044480  Twitter for iPhone  2019-08-11 17:59:16
# 9     @LilNasX  1160604352228184064  Twitter for iPhone  2019-08-11 17:30:15
# 10    @LilNasX  1160390539503476736  Twitter for iPhone  2019-08-11 03:20:38
# ...

# %%
dfc=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/@MichelleObama_tweets_V1.csv",encoding='utf-8')

# %%
dfd=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/@rihanna_tweets_V1.csv",encoding='utf-8')

# %%
dfd
# Out:
#      User_Name             Tweet_ID              Source         Created_date  \
# 0     @rihanna  1160659661739057152  Twitter for iPhone  2019-08-11 21:10:02
# 1     @rihanna  1160659657867911169  Twitter for iPhone  2019-08-11 21:10:01
# 2     @rihanna  1159945249797443584  Twitter for iPhone  2019-08-09 21:51:12
# 3     @rihanna  1158069410747375621  Twitter for iPhone  2019-08-04 17:37:18
# 4     @rihanna  1156582377696780289  Twitter for iPhone  2019-07-31 15:08:21
# 5     @rihanna  1156582047462432769  Twitter for iPhone  2019-07-31 15:07:03
# 6     @rihanna  1153752917519634437  Twitter for iPhone  2019-07-23 19:45:05
# 7     @rihanna  1152226907057868800  Twitter for iPhone  2019-07-19 14:41:16
# 8     @rihanna  1152046825215422465  Twitter for iPhone  2019-07-19 02:45:41
# 9     @rihanna  1152006145382289409  Twitter for iPhone  2019-07-19 00:04:02
# 10    @rihanna  1152006139539705856  Twitter for iPhone  2019-07-19 00:04:01
# ...

# %%
dff_row_merged = pd.concat([df1, dfa], ignore_index=True)

# %%
dfe=dff_row_merged

# %%
dfe
# Out:
#        User_Name      Tweet_ID                Source         Created_date  \
# 0     @BillGates  1.160000e+18              Sprinklr      8/10/2019 15:33
# 1     @BillGates  1.160000e+18              Sprinklr       8/9/2019 14:20
# 2     @BillGates  1.160000e+18              Sprinklr       8/7/2019 16:57
# 3     @BillGates  1.160000e+18              Sprinklr       8/5/2019 17:48
# 4     @BillGates  1.160000e+18              Sprinklr       8/1/2019 17:21
# 5     @BillGates  1.160000e+18              Sprinklr      7/29/2019 18:42
# 6     @BillGates  1.160000e+18              Sprinklr      7/29/2019 15:00
# 7     @BillGates  1.160000e+18              Sprinklr       7/29/2019 0:00
# 8     @BillGates  1.150000e+18              Sprinklr      7/26/2019 16:18
# 9     @BillGates  1.150000e+18              Sprinklr      7/23/2019 20:23
# 10    @BillGates  1.150000e+18              Sprinklr      7/21/2019 23:52
# 11    @BillGates  1.150000e+18              Sprinklr      7/20/2019 12:00
# ...

# %%
dff_row_merged = pd.concat([dfe, dfb], ignore_index=True)

# %%
dfg=dff_row_merged

# %%
dff_row_merged = pd.concat([dfg, dfc], ignore_index=True)

# %%
dfh=dff_row_merged

# %%
dff_row_merged = pd.concat([dfh, dfd], ignore_index=True)

# %%
finaldf=dff_row_merged

# %%
finaldf.to_csv("NEWTWEETS.csv",  encoding='utf-8')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Madhur Bhalkar'

# %%
dfp=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/@TheEllenShow_tweets_V1.csv",encoding='utf-8')

# %%
dfq=dfp.dropna()

# %%
dff_row_merged = pd.concat([finaldf, dfq], ignore_index=True)

# %%
newfinal=dff_row_merged

# %%
newfinal
# Out:
#            User_Name      Tweet_ID                Source     Created_date  \
# 0         @BillGates  1.160000e+18              Sprinklr  8/10/2019 15:33
# 1         @BillGates  1.160000e+18              Sprinklr   8/9/2019 14:20
# 2         @BillGates  1.160000e+18              Sprinklr   8/7/2019 16:57
# 3         @BillGates  1.160000e+18              Sprinklr   8/5/2019 17:48
# 4         @BillGates  1.160000e+18              Sprinklr   8/1/2019 17:21
# 5         @BillGates  1.160000e+18              Sprinklr  7/29/2019 18:42
# 6         @BillGates  1.160000e+18              Sprinklr  7/29/2019 15:00
# 7         @BillGates  1.160000e+18              Sprinklr   7/29/2019 0:00
# 8         @BillGates  1.150000e+18              Sprinklr  7/26/2019 16:18
# 9         @BillGates  1.150000e+18              Sprinklr  7/23/2019 20:23
# 10        @BillGates  1.150000e+18              Sprinklr  7/21/2019 23:52
# 11        @BillGates  1.150000e+18              Sprinklr  7/20/2019 12:00
# ...

# %%
newfinal.to_csv("FINALTWEETS.csv",  encoding='utf-8')

# %%
get_tweets("@BhalkarMadhur")
# Out:
# writing to @BhalkarMadhur_tweets_V1.csv

# %%
dfZ=pd.read_csv("C:/Users/Madhur Bhalkar/Desktop/CREATED DATA/@BhalkarMadhur_tweets_V1.csv",encoding='utf-8')

# %%
dfz=dfZ.dropna()

# %%
dfz.to_csv("MYTWEETSOK.csv",  encoding='utf-8')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Madhur Bhalkar'

# %%
get_tweets("@MTV")
# Out:
# writing to @MTV_tweets_V1.csv
